# %%
import os

import numpy as np
import pandas as pd

# %% [markdown]
# ## Obtener los nombres de la lista de elementos

# %%
direccion_dataset = "/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/" #Poner la dirección del dataset aquí
ruta_clinical_readings= os.path.join(direccion_dataset, "ClinicalReadings/")
ruta_cxr_png = os.path.join(direccion_dataset, "CXR_png/")
extension_cxr = "png"
extension_cr = "txt" #Extension Clinical Reading
lista_elementos_dataset = os.listdir(ruta_clinical_readings)
datos = np.zeros((len(lista_elementos_dataset),), dtype=[("path", np.str_), ("genre", np.str_), ("age", "f4"), ("condition", "a10")])

for idx, elemento in enumerate(lista_elementos_dataset):
    nombre_elemento = elemento.split(".")[0]
    ruta_elemento_cxr = os.path.join(ruta_cxr_png, "{}.{}".format(nombre_elemento, extension_cxr))
    ruta_elemento_cr = os.path.join(ruta_clinical_readings, "{}.{}".format(nombre_elemento, extension_cr))
    with open(ruta_elemento_cr, 'r') as archivo_texto:
        datos_archivo_texto = archivo_texto.read() #Obtengo la informacion del dataset
        print(datos_archivo_texto)
        datos_archivo_texto = datos_archivo_texto.rstrip() #Eliminar tabulación final
        datos_archivo_texto.replace("\t", "")
        atributos_archivo = datos_archivo_texto.split('\n') #Separar por enters
        condicion_paciente = atributos_archivo[-1] #Ultimo elemento
        genero = ""
        edad = 0
        print(ruta_elemento_cr)
        print(atributos_archivo)
        if "," in atributos_archivo[0]:
            genero_edad = atributos_archivo[0].rstrip().lstrip().split(",")
        
        else:
            genero_edad = atributos_archivo[0].rstrip().split(" ")
            #Verificar si el genero y la edad estan unidos
            if len(genero_edad) == 1:
                if genero_edad[0].find('female') == 0:
                    print("=================Female")
                    genero_edad.append(genero_edad[0].lstrip("female"))
                    genero_edad[0] = "female"
                    print("Arreglando: {}".format(genero_edad))
                elif genero_edad[0].find('male') == 0:
                    genero_edad.append(genero_edad[0].lstrip("male"))
                    genero_edad[0] = "male"
        #Eliminar los caracteres vacios
        genero_edad = [valido for valido in genero_edad if valido]

        genero, edad = genero_edad[0:2]

        if "yrs" in edad: #Convertir a int
            edad = edad.rstrip("yrs")
        elif "yr" in edad: #Convertir a int
            edad = edad.rstrip("yr")
        elif "month" in edad: #Convertir a int
            edad = edad.rstrip("month")
            edad = float(edad)/12.0
        elif "days" in edad: #Convertir a int
            edad = edad.rstrip("days")
            edad = float(edad)/365.0
        
        genero = genero.lower()
        edad = float(edad)
    ruta_elemento_clinical_reading = os.path.join(ruta_clinical_readings)
    print((ruta_elemento_cxr, genero, edad, condicion_paciente))
    datos[idx] = (ruta_elemento_cxr, genero, edad, condicion_paciente)
# Out:
# female 62yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0272_0.txt
# ['female 62yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0272_0.png', 'female', 62.0, 'normal')
# male 45yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0001_0.txt
# ['male 45yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0001_0.png', 'male', 45.0, 'normal')
# male 63yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0002_0.txt
# ['male 63yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0002_0.png', 'male', 63.0, 'normal')
# female 48yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0003_0.txt
# ['female 48yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0003_0.png', 'female', 48.0, 'normal')
# male 58yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0004_0.txt
# ['male 58yrs ', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0004_0.png', 'male', 58.0, 'normal')
# male 28yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0005_0.txt
# ['male 28yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0005_0.png', 'male', 28.0, 'normal')
# male 60yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0006_0.txt
# ['male 60yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0006_0.png', 'male', 60.0, 'normal')
# female 53yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0007_0.txt
# ['female 53yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0007_0.png', 'female', 53.0, 'normal')
# male 48yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0008_0.txt
# ['male 48yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0008_0.png', 'male', 48.0, 'normal')
# female 71yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0009_0.txt
# ['female 71yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0009_0.png', 'female', 71.0, 'normal')
# female 59yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0010_0.txt
# ['female 59yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0010_0.png', 'female', 59.0, 'normal')
# male 43yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0011_0.txt
# ['male 43yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0011_0.png', 'male', 43.0, 'normal')
# male 39yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0012_0.txt
# ['male 39yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0012_0.png', 'male', 39.0, 'normal')
# male 41yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0013_0.txt
# ['male 41yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0013_0.png', 'male', 41.0, 'normal')
# male 39yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0014_0.txt
# ['male 39yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0014_0.png', 'male', 39.0, 'normal')
# female 28yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0015_0.txt
# ['female 28yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0015_0.png', 'female', 28.0, 'normal')
# female 57yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0016_0.txt
# ['female 57yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0016_0.png', 'female', 57.0, 'normal')
# male 42
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0018_0.txt
# ['male 42', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0018_0.png', 'male', 42.0, 'normal')
# male 27yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0019_0.txt
# ['male 27yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0019_0.png', 'male', 27.0, 'normal')
# male 32yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0020_0.txt
# ['male 32yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0020_0.png', 'male', 32.0, 'normal')
# female 38yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0021_0.txt
# ['female 38yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0021_0.png', 'female', 38.0, 'normal')
# male 56yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0022_0.txt
# ['male 56yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0022_0.png', 'male', 56.0, 'normal')
# male 32yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0023_0.txt
# ['male 32yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0023_0.png', 'male', 32.0, 'normal')
# male 22yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0024_0.txt
# ['male 22yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0024_0.png', 'male', 22.0, 'normal')
# male 29yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0025_0.txt
# ['male 29yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0025_0.png', 'male', 29.0, 'normal')
# male 29yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0026_0.txt
# ['male 29yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0026_0.png', 'male', 29.0, 'normal')
# female 57yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0027_0.txt
# ['female 57yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0027_0.png', 'female', 57.0, 'normal')
# male 39yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0028_0.txt
# ['male 39yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0028_0.png', 'male', 39.0, 'normal')
# male 43yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0029_0.txt
# ['male 43yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0029_0.png', 'male', 43.0, 'normal')
# Female 38yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0030_0.txt
# ['Female 38yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0030_0.png', 'female', 38.0, 'normal')
# female 27yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0031_0.txt
# ['female 27yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0031_0.png', 'female', 27.0, 'normal')
# female 53yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0032_0.txt
# ['female 53yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0032_0.png', 'female', 53.0, 'normal')
# male 34yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0033_0.txt
# ['male 34yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0033_0.png', 'male', 34.0, 'normal')
# female 59yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0035_0.txt
# ['female 59yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0035_0.png', 'female', 59.0, 'normal')
# male 26yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0036_0.txt
# ['male 26yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0036_0.png', 'male', 26.0, 'normal')
# male 24yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0037_0.txt
# ['male 24yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0037_0.png', 'male', 24.0, 'normal')
# male 27yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0038_0.txt
# ['male 27yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0038_0.png', 'male', 27.0, 'normal')
# male 23yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0039_0.txt
# ['male 23yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0039_0.png', 'male', 23.0, 'normal')
# female 55yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0040_0.txt
# ['female 55yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0040_0.png', 'female', 55.0, 'normal')
# male 32yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0041_0.txt
# ['male 32yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0041_0.png', 'male', 32.0, 'normal')
# male 58yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0042_0.txt
# ['male 58yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0042_0.png', 'male', 58.0, 'normal')
# male 38yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0043_0.txt
# ['male 38yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0043_0.png', 'male', 38.0, 'normal')
# femal 32yrs
# normal
#
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0044_0.txt
# ['femal 32yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0044_0.png', 'femal', 32.0, 'normal')
# femal 60yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0045_0.txt
# ['femal 60yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0045_0.png', 'femal', 60.0, 'normal')
# male 44yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0046_0.txt
# ['male 44yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0046_0.png', 'male', 44.0, 'normal')
# male 34yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0047_0.txt
# ['male 34yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0047_0.png', 'male', 34.0, 'normal')
# male 23yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0048_0.txt
# ['male 23yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0048_0.png', 'male', 23.0, 'normal')
# female 35yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0049_0.txt
# ['female 35yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0049_0.png', 'female', 35.0, 'normal')
# female 38yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0050_0.txt
# ['female 38yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0050_0.png', 'female', 38.0, 'normal')
# female 35yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0052_0.txt
# ['female 35yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0052_0.png', 'female', 35.0, 'normal')
# male 52yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0053_0.txt
# ['male 52yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0053_0.png', 'male', 52.0, 'normal')
# female 25yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0054_0.txt
# ['female 25yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0054_0.png', 'female', 25.0, 'normal')
# male 41yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0055_0.txt
# ['male 41yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0055_0.png', 'male', 41.0, 'normal')
# male 48yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0056_0.txt
# ['male 48yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0056_0.png', 'male', 48.0, 'normal')
# female 54yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0057_0.txt
# ['female 54yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0057_0.png', 'female', 54.0, 'normal')
# female 56yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0058_0.txt
# ['female 56yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0058_0.png', 'female', 56.0, 'normal')
# male 68yrs
#
# normale
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0059_0.txt
# ['male 68yrs ', '', 'normale']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0059_0.png', 'male', 68.0, 'normale')
# female 33yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0060_0.txt
# ['female 33yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0060_0.png', 'female', 33.0, 'normal')
# male 23yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0061_0.txt
# ['male 23yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0061_0.png', 'male', 23.0, 'normal')
# female 28yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0062_0.txt
# ['female 28yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0062_0.png', 'female', 28.0, 'normal')
# female 29yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0063_0.txt
# ['female 29yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0063_0.png', 'female', 29.0, 'normal')
# male 36yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0064_0.txt
# ['male 36yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0064_0.png', 'male', 36.0, 'normal')
# female 22yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0065_0.txt
# ['female 22yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0065_0.png', 'female', 22.0, 'normal')
# male 36yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0066_0.txt
# ['male 36yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0066_0.png', 'male', 36.0, 'normal')
# male 32yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0067_0.txt
# ['male 32yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0067_0.png', 'male', 32.0, 'normal')
# male 35yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0017_0.txt
# ['male 35yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0017_0.png', 'male', 35.0, 'normal')
# female 60yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0034_0.txt
# ['female 60yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0034_0.png', 'female', 60.0, 'normal')
# female 63yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0051_0.txt
# ['female 63yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0051_0.png', 'female', 63.0, 'normal')
# male 31yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0068_0.txt
# ['male 31yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0068_0.png', 'male', 31.0, 'normal')
# male 42yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0085_0.txt
# ['male 42yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0085_0.png', 'male', 42.0, 'normal')
# female 25yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0102_0.txt
# ['female 25yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0102_0.png', 'female', 25.0, 'normal')
# male 20yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0119_0.txt
# ['male 20yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0119_0.png', 'male', 20.0, 'normal')
# male 30yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0136_0.txt
# ['male 30yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0136_0.png', 'male', 30.0, 'normal')
# female 37yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0153_0.txt
# ['female 37yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0153_0.png', 'female', 37.0, 'normal')
# male 23yrs
# normal
#
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0170_0.txt
# ['male 23yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0170_0.png', 'male', 23.0, 'normal')
# male 23yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0187_0.txt
# ['male 23yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0187_0.png', 'male', 23.0, 'normal')
# male 24yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0204_0.txt
# ['male 24yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0204_0.png', 'male', 24.0, 'normal')
# male 29yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0221_0.txt
# ['male 29yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0221_0.png', 'male', 29.0, 'normal')
# male 42yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0238_0.txt
# ['male 42yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0238_0.png', 'male', 42.0, 'normal')
# male 33yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0255_0.txt
# ['male 33yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0255_0.png', 'male', 33.0, 'normal')
# female 46yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0069_0.txt
# ['female 46yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0069_0.png', 'female', 46.0, 'normal')
# female 20yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0070_0.txt
# ['female 20yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0070_0.png', 'female', 20.0, 'normal')
# female 39yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0071_0.txt
# ['female 39yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0071_0.png', 'female', 39.0, 'normal')
# male 25yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0072_0.txt
# ['male 25yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0072_0.png', 'male', 25.0, 'normal')
# female 34yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0073_0.txt
# ['female 34yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0073_0.png', 'female', 34.0, 'normal')
# male 3yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0074_0.txt
# ['male 3yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0074_0.png', 'male', 3.0, 'normal')
# female 1 yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0075_0.txt
# ['female 1 yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0075_0.png', 'female', 1.0, 'normal')
# male 1yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0076_0.txt
# ['male 1yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0076_0.png', 'male', 1.0, 'normal')
# male 28yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0077_0.txt
# ['male 28yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0077_0.png', 'male', 28.0, 'normal')
# male 31yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0078_0.txt
# ['male 31yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0078_0.png', 'male', 31.0, 'normal')
# male 30yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0079_0.txt
# ['male 30yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0079_0.png', 'male', 30.0, 'normal')
# male 39yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0080_0.txt
# ['male 39yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0080_0.png', 'male', 39.0, 'normal')
# male 37yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0081_0.txt
# ['male 37yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0081_0.png', 'male', 37.0, 'normal')
# male 45yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0082_0.txt
# ['male 45yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0082_0.png', 'male', 45.0, 'normal')
# male 37yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0083_0.txt
# ['male 37yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0083_0.png', 'male', 37.0, 'normal')
# female 27yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0084_0.txt
# ['female 27yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0084_0.png', 'female', 27.0, 'normal')
# female 53yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0086_0.txt
# ['female 53yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0086_0.png', 'female', 53.0, 'normal')
# male 28yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0087_0.txt
# ['male 28yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0087_0.png', 'male', 28.0, 'normal')
# male 30yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0088_0.txt
# ['male 30yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0088_0.png', 'male', 30.0, 'normal')
# male 39yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0089_0.txt
# ['male 39yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0089_0.png', 'male', 39.0, 'normal')
# male 39yrs
#
# normal
#
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0090_0.txt
# ['male 39yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0090_0.png', 'male', 39.0, 'normal')
# male 37yrs
#
# normal
#
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0091_0.txt
# ['male 37yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0091_0.png', 'male', 37.0, 'normal')
# male 37yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0092_0.txt
# ['male 37yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0092_0.png', 'male', 37.0, 'normal')
# male 27yrs
#
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0093_0.txt
# ['male 27yrs', '', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0093_0.png', 'male', 27.0, 'normal')
# female 24yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0094_0.txt
# ['female 24yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0094_0.png', 'female', 24.0, 'normal')
# male 18yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0095_0.txt
# ['male 18yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0095_0.png', 'male', 18.0, 'normal')
# femal 69yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0096_0.txt
# ['femal 69yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0096_0.png', 'femal', 69.0, 'normal')
# female 30yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0097_0.txt
# ['female 30yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0097_0.png', 'female', 30.0, 'normal')
# male 54yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0098_0.txt
# ['male 54yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0098_0.png', 'male', 54.0, 'normal')
# female 26yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0099_0.txt
# ['female 26yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0099_0.png', 'female', 26.0, 'normal')
# male 25yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0100_0.txt
# ['male 25yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0100_0.png', 'male', 25.0, 'normal')
# male 23yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0101_0.txt
# ['male 23yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0101_0.png', 'male', 23.0, 'normal')
# female 25yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0103_0.txt
# ['female 25yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0103_0.png', 'female', 25.0, 'normal')
# male 43yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0104_0.txt
# ['male 43yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0104_0.png', 'male', 43.0, 'normal')
# male 22yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0105_0.txt
# ['male 22yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0105_0.png', 'male', 22.0, 'normal')
# male 26yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0106_0.txt
# ['male 26yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0106_0.png', 'male', 26.0, 'normal')
# female 36yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0107_0.txt
# ['female 36yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0107_0.png', 'female', 36.0, 'normal')
# male 22yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0108_0.txt
# ['male 22yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0108_0.png', 'male', 22.0, 'normal')
# female 21yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0109_0.txt
# ['female 21yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0109_0.png', 'female', 21.0, 'normal')
# male 42yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0110_0.txt
# ['male 42yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0110_0.png', 'male', 42.0, 'normal')
# male 44yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0111_0.txt
# ['male 44yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0111_0.png', 'male', 44.0, 'normal')
# male 33yrs
# normal
#
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0112_0.txt
# ['male 33yrs ', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0112_0.png', 'male', 33.0, 'normal')
# male 30yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0113_0.txt
# ['male 30yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0113_0.png', 'male', 30.0, 'normal')
# male 20yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0114_0.txt
# ['male 20yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0114_0.png', 'male', 20.0, 'normal')
# male 16month
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0115_0.txt
# ['male 16month', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0115_0.png', 'male', 1.3333333333333333, 'normal')
# male 49yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0116_0.txt
# ['male 49yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0116_0.png', 'male', 49.0, 'normal')
# male 48yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0117_0.txt
# ['male 48yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0117_0.png', 'male', 48.0, 'normal')
# female 26yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0118_0.txt
# ['female 26yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0118_0.png', 'female', 26.0, 'normal')
# male 19yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0120_0.txt
# ['male 19yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0120_0.png', 'male', 19.0, 'normal')
# male 21yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0121_0.txt
# ['male 21yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0121_0.png', 'male', 21.0, 'normal')
# female 20yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0122_0.txt
# ['female 20yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0122_0.png', 'female', 20.0, 'normal')
# female 64yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0123_0.txt
# ['female 64yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0123_0.png', 'female', 64.0, 'normal')
# male 34yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0124_0.txt
# ['male 34yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0124_0.png', 'male', 34.0, 'normal')
# male 30yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0125_0.txt
# ['male 30yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0125_0.png', 'male', 30.0, 'normal')
# female 65yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0126_0.txt
# ['female 65yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0126_0.png', 'female', 65.0, 'normal')
# female 24yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0127_0.txt
# ['female 24yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0127_0.png', 'female', 24.0, 'normal')
# male 28yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0128_0.txt
# ['male 28yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0128_0.png', 'male', 28.0, 'normal')
# female 43yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0129_0.txt
# ['female 43yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0129_0.png', 'female', 43.0, 'normal')
# male 26yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0130_0.txt
# ['male 26yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0130_0.png', 'male', 26.0, 'normal')
# male 19yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0131_0.txt
# ['male 19yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0131_0.png', 'male', 19.0, 'normal')
# female 50yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0132_0.txt
# ['female 50yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0132_0.png', 'female', 50.0, 'normal')
# male 28yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0133_0.txt
# ['male 28yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0133_0.png', 'male', 28.0, 'normal')
# male 29yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0134_0.txt
# ['male 29yrs ', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0134_0.png', 'male', 29.0, 'normal')
# male 20yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0135_0.txt
# ['male 20yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0135_0.png', 'male', 20.0, 'normal')
# male 24yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0137_0.txt
# ['male 24yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0137_0.png', 'male', 24.0, 'normal')
# female  30yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0138_0.txt
# ['female  30yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0138_0.png', 'female', 30.0, 'normal')
# female  27yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0139_0.txt
# ['female  27yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0139_0.png', 'female', 27.0, 'normal')
# female  39yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0140_0.txt
# ['female  39yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0140_0.png', 'female', 39.0, 'normal')
# female 36yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0141_0.txt
# ['female 36yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0141_0.png', 'female', 36.0, 'normal')
# male 22yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0142_0.txt
# ['male 22yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0142_0.png', 'male', 22.0, 'normal')
# female 47yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0143_0.txt
# ['female 47yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0143_0.png', 'female', 47.0, 'normal')
# male 31yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0144_0.txt
# ['male 31yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0144_0.png', 'male', 31.0, 'normal')
# male 45yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0145_0.txt
# ['male 45yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0145_0.png', 'male', 45.0, 'normal')
# male  22yrs
# normal
#
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0146_0.txt
# ['male  22yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0146_0.png', 'male', 22.0, 'normal')
# male 23yrs
# normal
#
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0147_0.txt
# ['male 23yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0147_0.png', 'male', 23.0, 'normal')
# male 24yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0148_0.txt
# ['male 24yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0148_0.png', 'male', 24.0, 'normal')
# male 31yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0149_0.txt
# ['male 31yrs ', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0149_0.png', 'male', 31.0, 'normal')
# male 45yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0150_0.txt
# ['male 45yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0150_0.png', 'male', 45.0, 'normal')
# female 25yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0151_0.txt
# ['female 25yrs ', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0151_0.png', 'female', 25.0, 'normal')
# female 24yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0152_0.txt
# ['female 24yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0152_0.png', 'female', 24.0, 'normal')
# male 31yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0154_0.txt
# ['male 31yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0154_0.png', 'male', 31.0, 'normal')
# male 5yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0155_0.txt
# ['male 5yrs ', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0155_0.png', 'male', 5.0, 'normal')
# female  38yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0156_0.txt
# ['female  38yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0156_0.png', 'female', 38.0, 'normal')
# male 23yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0157_0.txt
# ['male 23yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0157_0.png', 'male', 23.0, 'normal')
# female 36yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0158_0.txt
# ['female 36yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0158_0.png', 'female', 36.0, 'normal')
# male 22yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0159_0.txt
# ['male 22yrs ', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0159_0.png', 'male', 22.0, 'normal')
# female 23yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0160_0.txt
# ['female 23yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0160_0.png', 'female', 23.0, 'normal')
# female 48yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0161_0.txt
# ['female 48yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0161_0.png', 'female', 48.0, 'normal')
# male 23yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0162_0.txt
# ['male 23yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0162_0.png', 'male', 23.0, 'normal')
# male 28yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0163_0.txt
# ['male 28yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0163_0.png', 'male', 28.0, 'normal')
# male 53yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0164_0.txt
# ['male 53yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0164_0.png', 'male', 53.0, 'normal')
# male 39yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0165_0.txt
# ['male 39yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0165_0.png', 'male', 39.0, 'normal')
# female 31yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0166_0.txt
# ['female 31yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0166_0.png', 'female', 31.0, 'normal')
# male 47yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0167_0.txt
# ['male 47yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0167_0.png', 'male', 47.0, 'normal')
# male 27yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0168_0.txt
# ['male 27yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0168_0.png', 'male', 27.0, 'normal')
# male 2yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0169_0.txt
# ['male 2yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0169_0.png', 'male', 2.0, 'normal')
# male 19yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0171_0.txt
# ['male 19yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0171_0.png', 'male', 19.0, 'normal')
# female 26yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0172_0.txt
# ['female 26yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0172_0.png', 'female', 26.0, 'normal')
# male 28yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0173_0.txt
# ['male 28yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0173_0.png', 'male', 28.0, 'normal')
# male 68yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0174_0.txt
# ['male 68yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0174_0.png', 'male', 68.0, 'normal')
# female 70yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0175_0.txt
# ['female 70yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0175_0.png', 'female', 70.0, 'normal')
# female 64yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0176_0.txt
# ['female 64yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0176_0.png', 'female', 64.0, 'normal')
# male 19yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0177_0.txt
# ['male 19yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0177_0.png', 'male', 19.0, 'normal')
# male 1yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0178_0.txt
# ['male 1yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0178_0.png', 'male', 1.0, 'normal')
# male 22yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0179_0.txt
# ['male 22yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0179_0.png', 'male', 22.0, 'normal')
# female 36yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0180_0.txt
# ['female 36yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0180_0.png', 'female', 36.0, 'normal')
# female 43yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0181_0.txt
# ['female 43yrs', 'normal']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0181_0.png', 'female', 43.0, 'normal')
# male 37yrs
# normal
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0182_0.txt
# ['male 37yrs', 'normal']
# ...
# female 38yrs
# PTB in the left upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0619_1.txt
# ['female 38yrs  \t', 'PTB in the left upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0619_1.png', 'female', 38.0, 'PTB in the left upper field')
# male 37yrs
# PTB in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0620_1.txt
# ['male 37yrs  \t', 'PTB in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0620_1.png', 'male', 37.0, 'PTB in the right upper field')
# male 42yrs
# Right PTB
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0621_1.txt
# ['male 42yrs  \t', 'Right PTB']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0621_1.png', 'male', 42.0, 'Right PTB')
# female 49yrs
# left PTB
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0622_1.txt
# ['female 49yrs  \t', 'left PTB']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0622_1.png', 'female', 49.0, 'left PTB')
# female 39yrs
# PTB in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0623_1.txt
# ['female 39yrs  \t', 'PTB in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0623_1.png', 'female', 39.0, 'PTB in the right upper field')
# female 76yrs
# PTB in the left upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0624_1.txt
# ['female 76yrs  \t', 'PTB in the left upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0624_1.png', 'female', 76.0, 'PTB in the left upper field')
# male 30yrs
# PTB in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0625_1.txt
# ['male 30yrs  \t', 'PTB in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0625_1.png', 'male', 30.0, 'PTB in the right upper field')
# male 49yrs
# PTB in the right lower field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0626_1.txt
# ['male 49yrs  \t', 'PTB in the right lower field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0626_1.png', 'male', 49.0, 'PTB in the right lower field')
# female 26yrs
# secondary PTB  in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0627_1.txt
# ['female 26yrs  \t', 'secondary PTB  in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0627_1.png', 'female', 26.0, 'secondary PTB  in the right upper field')
# male 27yrs
# secondary PTB  in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0628_1.txt
# ['male 27yrs  \t', 'secondary PTB  in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0628_1.png', 'male', 27.0, 'secondary PTB  in the right upper field')
# male 2yrs
# secondary PTB  in the bilateral upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0630_1.txt
# ['male 2yrs  \t', 'secondary PTB  in the bilateral upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0630_1.png', 'male', 2.0, 'secondary PTB  in the bilateral upper field')
# female 28yrs
# secondary PTB  in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0631_1.txt
# ['female 28yrs  \t', 'secondary PTB  in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0631_1.png', 'female', 28.0, 'secondary PTB  in the right upper field')
# female 30yrs
# PTB in the left upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0632_1.txt
# ['female 30yrs  \t', 'PTB in the left upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0632_1.png', 'female', 30.0, 'PTB in the left upper field')
# male35yrs
# PTB in the left upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0633_1.txt
# ['male35yrs  \t', 'PTB in the left upper field']
# 1
# False
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0633_1.png', 'male', 35.0, 'PTB in the left upper field')
# male 28yrs
# secondary PTB  in the bilateral upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0634_1.txt
# ['male 28yrs  \t', 'secondary PTB  in the bilateral upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0634_1.png', 'male', 28.0, 'secondary PTB  in the bilateral upper field')
# male 65yrs
# bilateral PTB
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0635_1.txt
# ['male 65yrs  \t', 'bilateral PTB']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0635_1.png', 'male', 65.0, 'bilateral PTB')
# male35yrs
# Bilateral secondary PTB
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0636_1.txt
# ['male35yrs  \t', 'Bilateral secondary PTB']
# 1
# False
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0636_1.png', 'male', 35.0, 'Bilateral secondary PTB')
# male 44yrs
# bilateral PTB
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0637_1.txt
# ['male 44yrs  \t', 'bilateral PTB']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0637_1.png', 'male', 44.0, 'bilateral PTB')
# Female 36yrs
# Bilateral secondary PTB with left lower field pneumonia
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0638_1.txt
# ['Female 36yrs  \t', 'Bilateral secondary PTB with left lower field pneumonia']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0638_1.png', 'female', 36.0, 'Bilateral secondary PTB with left lower field pneumonia')
# Female, 28yrs
# bilateral acute hematogenous disseminated PTB
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0639_1.txt
# ['Female, 28yrs  \t', 'bilateral acute hematogenous disseminated PTB']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0639_1.png', 'female', 28.0, 'bilateral acute hematogenous disseminated PTB')
# Male 38yrs
# Bilateral secondary PTB  with most lesions calcified
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0640_1.txt
# ['Male 38yrs  \t', 'Bilateral secondary PTB  with most lesions calcified']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0640_1.png', 'male', 38.0, 'Bilateral secondary PTB  with most lesions calcified')
# Female, 28yrs
# left secondary PTB
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0641_1.txt
# ['Female, 28yrs  \t', 'left secondary PTB']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0641_1.png', 'female', 28.0, 'left secondary PTB')
# Female, 43yrs
# secondary PTB  in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0642_1.txt
# ['Female, 43yrs  \t', 'secondary PTB  in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0642_1.png', 'female', 43.0, 'secondary PTB  in the right upper field')
# Male, 43yrs
# secondary PTB  in the bilateral upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0643_1.txt
# ['Male, 43yrs  \t', 'secondary PTB  in the bilateral upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0643_1.png', 'male', 43.0, 'secondary PTB  in the bilateral upper field')
# Female, 44yrs
# 1.secondary PTB  in the right upper field; 2.small tuberculoma; 3.right pleural thickening and adhesions
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0644_1.txt
# ['Female, 44yrs  \t', '1.secondary PTB  in the right upper field; 2.small tuberculoma; 3.right pleural thickening and adhesions']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0644_1.png', 'female', 44.0, '1.secondary PTB  in the right upper field; 2.small tuberculoma; 3.right pleural thickening and adhesions')
# Male , 27yrs
# Left secondary PTB in the upper and middle fields, mainly  fibrous  lesions
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0645_1.txt
# ['Male , 27yrs  \t', 'Left secondary PTB in the upper and middle fields, mainly  fibrous  lesions']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0645_1.png', 'male ', 27.0, 'Left secondary PTB in the upper and middle fields, mainly  fibrous  lesions')
# Male, 31yrs
# secondary PTB  in the left lower field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0646_1.txt
# ['Male, 31yrs  \t', 'secondary PTB  in the left lower field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0646_1.png', 'male', 31.0, 'secondary PTB  in the left lower field')
# Male , 38yrs,
# secondary PTB in the bilateral upper and middle fields, mainly fibrous  lesions
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0647_1.txt
# ['Male , 38yrs,  \t', 'secondary PTB in the bilateral upper and middle fields, mainly fibrous  lesions']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0647_1.png', 'male ', 38.0, 'secondary PTB in the bilateral upper and middle fields, mainly fibrous  lesions')
# Male, 26yrs
# bilateral secondary PTB with multiple cavitations
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0648_1.txt
# ['Male, 26yrs  \t', 'bilateral secondary PTB with multiple cavitations']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0648_1.png', 'male', 26.0, 'bilateral secondary PTB with multiple cavitations')
# Male , 29yrs
# bilateral secondary PTB,mainly hyperplastic lesions
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0649_1.txt
# ['Male , 29yrs  \t', 'bilateral secondary PTB,mainly hyperplastic lesions']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0649_1.png', 'male ', 29.0, 'bilateral secondary PTB,mainly hyperplastic lesions')
# Male , 50yrs
# secondary PTB  in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0650_1.txt
# ['Male , 50yrs  \t', 'secondary PTB  in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0650_1.png', 'male ', 50.0, 'secondary PTB  in the right upper field')
# Female, 49yrs
# Right secondary PTB,mainly hyperplastic lesions
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0651_1.txt
# ['Female, 49yrs  \t', 'Right secondary PTB,mainly hyperplastic lesions']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0651_1.png', 'female', 49.0, 'Right secondary PTB,mainly hyperplastic lesions')
# Male, 51yrs
# secondary PTB  in thel left upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0652_1.txt
# ['Male, 51yrs  \t', 'secondary PTB  in thel left upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0652_1.png', 'male', 51.0, 'secondary PTB  in thel left upper field')
# Male, 69yrs
# bilateral secondary PTB  with pleural thickening
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0653_1.txt
# ['Male, 69yrs  \t', 'bilateral secondary PTB  with pleural thickening']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0653_1.png', 'male', 69.0, 'bilateral secondary PTB  with pleural thickening')
# Male , 28yrs
# Right secondary PTB
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0654_1.txt
# ['Male , 28yrs  \t', 'Right secondary PTB']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0654_1.png', 'male ', 28.0, 'Right secondary PTB')
# Male 33yrs
# secondary PTB in the right upper field,mainly hyperplastic lesions
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0655_1.txt
# ['Male 33yrs  \t', 'secondary PTB in the right upper field,mainly hyperplastic lesions']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0655_1.png', 'male', 33.0, 'secondary PTB in the right upper field,mainly hyperplastic lesions')
# Female 35yrs
# secondary PTB  in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0656_1.txt
# ['Female 35yrs  \t', 'secondary PTB  in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0656_1.png', 'female', 35.0, 'secondary PTB  in the right upper field')
# Male , 31yrs
# Right secondary PTB in the upper and middle fields
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0657_1.txt
# ['Male , 31yrs  \t', 'Right secondary PTB in the upper and middle fields']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0657_1.png', 'male ', 31.0, 'Right secondary PTB in the upper and middle fields')
# Male 41yrs
# bilateral secondary PTB  with right pneumothorax
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0658_1.txt
# ['Male 41yrs  \t', 'bilateral secondary PTB  with right pneumothorax']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0658_1.png', 'male', 41.0, 'bilateral secondary PTB  with right pneumothorax')
# Male , 33yrs
# secondary PTB  in the left upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0659_1.txt
# ['Male , 33yrs  \t', 'secondary PTB  in the left upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0659_1.png', 'male ', 33.0, 'secondary PTB  in the left upper field')
# Male , 50yrs
# 1.bilateral secondary PTB  with right upper atelectasis;2.right pleural adhesions;3.left compensatory emphysema
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0660_1.txt
# ['Male , 50yrs  \t', '1.bilateral secondary PTB  with right upper atelectasis;2.right pleural adhesions;3.left compensatory emphysema']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0660_1.png', 'male ', 50.0, '1.bilateral secondary PTB  with right upper atelectasis;2.right pleural adhesions;3.left compensatory emphysema')
# Male, 26yrs
# bilateral secondary PTB  with right pleural thickening
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0661_1.txt
# ['Male, 26yrs  \t', 'bilateral secondary PTB  with right pleural thickening']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0661_1.png', 'male', 26.0, 'bilateral secondary PTB  with right pleural thickening')
# Male , 32yrs
# secondary PTB  in the right upper field
# /media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/ClinicalReadings/CHNCXR_0662_1.txt
# ['Male , 32yrs  \t', 'secondary PTB  in the right upper field']
# ('/media/josejacomeb/Datos1/DatasetsMédicos/ChinaSet_AllFiles/CXR_png/CHNCXR_0662_1.png', 'male ', 32.0, 'secondary PTB  in the right upper field')

# %%
panda_datos = pd.DataFrame(datos)

# %%
panda_datos["genre"]
# Out:
# 0
# 1
# 2
# 3
# 4
#       ..
# 657
# 658
# 659
# 660
# 661
# Name: genre, Length: 662, dtype: object
